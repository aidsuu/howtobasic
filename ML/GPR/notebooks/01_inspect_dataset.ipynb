# %% [markdown]
# # 01 Inspect Dataset
#
# Notebook ini menjalankan inspeksi dasar untuk dataset MERL-GPR secara read-only.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent
SRC_DIR = PROJECT_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

from inspect_dataset import run_inspection

# %%
DATASET_ROOT = PROJECT_ROOT / "data" / "MERLGPR"
DATASET_ROOT

# %%
run_inspection(
    dataset_root=DATASET_ROOT,
    max_depth=4,
    max_entries_per_dir=8,
    max_samples_per_ext=5,
    max_array_items=40,
)
